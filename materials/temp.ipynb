# %%
class computer:
    def __init__(self, maker, model, year):
        self.maker = maker
        self.model = model
        self.year = year
    
    def turnOn(self):
        print(f"{self.maker} {self.model} is turning on")
        
computer1 = computer("Dell", "XPS 13", "2023")
computer2 = computer("HP", "Spectre x360", "2022")
computer3 = computer("Lenovo", "ThinkPad X1 Carbon", "2024")
computer4 = computer("Asus", "Zenbook 14", "2021")
computer5 = computer("Acer", "Swift 3", "2020")
computer6 = computer("Microsoft", "Surface Laptop 4", "2022")
computer7 = computer("Razer", "Blade 15", "2023")
computer8 = computer("Samsung", "Galaxy Book Pro", "2021")
computer9 = computer("LG", "Gram 17", "2022")
computer10 = computer("MSI", "Modern 14", "2020")
computer11 = computer("Apple", "iMac", "2023")
computer12 = computer("Apple", "Mac mini", "2022")
computer13 = computer("Apple", "Mac Studio", "2022")
computer14 = computer("Huawei", "MateBook X Pro", "2021")
computer15 = computer("Xiaomi", "Mi Notebook Pro", "2022")
computer16 = computer("Google", "Pixelbook Go", "2019")
computer17 = computer("Framework", "Laptop DIY Edition", "2022")
computer18 = computer("System76", "Lemur Pro", "2023")
computer19 = computer("Tuxedo Computers", "InfinityBook Pro 14", "2021")
computer20 = computer("Star Labs", "StarLite Mk IV", "2022")

computer2.turnOn()

# %%
import math

x = 4
print(math.log(x))
print(math.log(math.e))
# Out:
# 1.3862943611198906
# 1.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# Define the actual and predicted values
y_true = np.array([actual_values])  # Replace with your actual values
y_pred = np.array([predicted_values])  # Replace with your predicted values

# Number of observations
n = len(y_true)

# Mean Absolute Error (MAE)
mae = np.sum(np.abs(y_true - y_pred)) / n

# Mean Squared Error (MSE)
mse = np.sum((y_true - y_pred) ** 2) / n

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
